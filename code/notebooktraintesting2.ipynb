# %% [markdown]
# Check on GPU

# %%
# !nvidia-smi
# Out:
# Thu Feb 12 10:18:20 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.83                 Driver Version: 572.83         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   41C    P8            N/A  /  115W |     935MiB /   8188MiB |     11%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
torch.cuda.is_available()

#get gpu details
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Name: NVIDIA GeForce RTX 4060

# %% [markdown]
# --------------------------------------------------------
# Training new models
# -------------------------------------------------------

# %%
# !yolo task=detect mode=train model=yolov8n.pt imgsz=512 data=RCS_dataset_v06.yaml epochs=50 batch=24 name=yolov8n_v8_50e_15 device=0

# %% [markdown]
# ------------------------------------------------
# Evaluating each model using the test dataset
# -------------------------------------------------

# %%
# !yolo task=detect mode=val model=[trained_model_name.pt] data=RCS_dataset_v06.yaml split=test name=[output_filename]  conf=0.3 iou=0.7 imgsz=512 save_json=True device=0

# %% [markdown]
# -----------------------------------------------------
# Test model on images
# ------------------------------------------------------

# %%
# !yolo task=detect mode=predict model=[trained_model_name.pt] source= [test_image.jpg] name=[output_filename.jpg] device=0 imgsz=512 show_labels=False show_conf=False
